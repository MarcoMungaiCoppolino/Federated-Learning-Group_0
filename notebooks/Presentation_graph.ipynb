# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset

batch_size = [512, 512, 1000, 2000, 4000, 8000, 16000, 32000, 64000]
f1_score = [90.395, 91.752, 91.761, 91.946, 91.137, 91.263, 91.345, 91.475, 90.584]
time_hours = [81.4, 82.8, 43.2, 21.4, 693.6/60, 390.5/60, 200.0/60, 101.2/60, 76.19/60]

# Indices for different experiments
first_two_indices = [0, 1]
last_index = [8]
regular_indices = [2, 3, 4, 5, 6, 7]

# Function to format the x-axis labels
def format_k(x, pos):
    if x >= 1000:
        return f'{int(x/1000)}k'
    else:
        return f'{int(x)}'

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Create the first graph (F1 score)
ax1.scatter([batch_size[i] for i in first_two_indices], [f1_score[i] for i in first_two_indices], color='red', marker='s', label='Small Batch Size')
ax1.scatter([batch_size[i] for i in regular_indices], [f1_score[i] for i in regular_indices], color='blue', marker='o', label='First Optimization')
ax1.scatter([batch_size[i] for i in last_index], [f1_score[i] for i in last_index], color='green', marker='^', label='Mixed-Batch Training')
# Add labels next to the first two points
ax1.text(batch_size[first_two_indices[0]]*2.5, f1_score[first_two_indices[0]]+0.08, 'Baseline', fontsize=12, verticalalignment='bottom', horizontalalignment='right', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
ax1.text(batch_size[first_two_indices[1]], f1_score[first_two_indices[1]]+0.07, 'Lamb', fontsize=12, verticalalignment='bottom', horizontalalignment='left', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

ax1.set_xscale('log')
ax1.set_xlabel('Batch Size')
ax1.set_ylabel('F1 Score on Dev Set')
ax1.set_title('F1 Score vs Batch Size')
ax1.grid(True)
ax1.xaxis.set_major_formatter(ticker.FuncFormatter(format_k))
ax1.set_xticks(batch_size)
ax1.legend()

# Create inset of the second graph
axins = zoomed_inset_axes(ax2, 2, loc='center right')
axins.scatter([batch_size[i] for i in first_two_indices], [time_hours[i] for i in first_two_indices], color='red', marker='s')
axins.scatter([batch_size[i] for i in last_index], [time_hours[i] for i in last_index], color='green', marker='^')
axins.scatter([batch_size[i] for i in regular_indices], [time_hours[i] for i in regular_indices], color='blue', marker='o')
axins.set_xlim(400, 650)
axins.set_ylim(80, 84)
plt.xticks(visible=False)
plt.yticks(visible=False)
mark_inset(ax2, axins, loc1=3, loc2=1, fc="none", ec="0.5")

# Create the second graph (Time)
ax2.scatter([batch_size[i] for i in first_two_indices], [time_hours[i] for i in first_two_indices], color='red', marker='s', label='Small Batch Size')
ax2.scatter([batch_size[i] for i in regular_indices], [time_hours[i] for i in regular_indices], color='blue', marker='o', label='First Optimization')
ax2.scatter([batch_size[i] for i in last_index], [time_hours[i] for i in last_index], color='green', marker='^', label='Mixed-Batch Training')

# Add labels next to the first two points
ax2.text(batch_size[first_two_indices[0]]*77, time_hours[first_two_indices[0]]-50, 'Baseline', fontsize=12, verticalalignment='bottom', horizontalalignment='right', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
ax2.text(batch_size[first_two_indices[1]]*75, time_hours[first_two_indices[1]]-34, 'Lamb', fontsize=12, verticalalignment='bottom', horizontalalignment='left', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

ax2.set_xscale('log')
ax2.set_xlabel('Batch Size')
ax2.set_ylabel('Time (hours)')
ax2.set_title('Time vs Batch Size')
ax2.grid(True)
ax2.xaxis.set_major_formatter(ticker.FuncFormatter(format_k))
ax2.set_xticks(batch_size)
ax2.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes, mark_inset

batch_size = [512, 512, 1000, 2000, 4000, 8000, 16000, 32000, 64000]
f1_score = [90.395, 91.752, 91.761, 91.946, 91.137, 91.263, 91.345, 91.475, 90.584]
time_hours = [81.4, 82.8, 43.2, 21.4, 693.6/60, 390.5/60, 200.0/60, 101.2/60, 76.19/60]

# Indices for different experiments
first_two_indices = [0, 1]
last_index = [8]
regular_indices = [2, 3, 4, 5, 6, 7]

# Function to format the x-axis labels
def format_k(x, pos):
    if x >= 1000:
        return f'{int(x/1000)}k'
    else:
        return f'{int(x)}'

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Create the first graph (F1 score)
ax1.plot([batch_size[i] for i in first_two_indices], [f1_score[i] for i in first_two_indices], color='red', marker='s', label='Small Batch Size')
ax1.plot([batch_size[i] for i in last_index], [f1_score[i] for i in last_index], color='green', marker='^', label='First Optimization')
ax1.plot([batch_size[i] for i in regular_indices], [f1_score[i] for i in regular_indices], color='blue', marker='o', label='Mixed-Batch Training')

# Create the second graph (Time)
ax2.plot([batch_size[i] for i in first_two_indices], [time_hours[i] for i in first_two_indices], color='red', marker='s', label='Small Batch Size')
ax2.plot([batch_size[i] for i in last_index], [time_hours[i] for i in last_index], color='green', marker='^', label='First Optimization')
ax2.plot([batch_size[i] for i in regular_indices], [time_hours[i] for i in regular_indices], color='blue', marker='o', label='Mixed-Batch Training')

# Connect the dots with different colors
ax1.plot(batch_size[first_two_indices], f1_score[first_two_indices], color='red')
ax1.plot([batch_size[first_two_indices[-1]], batch_size[regular_indices[0]]], [f1_score[first_two_indices[-1]], f1_score[regular_indices[0]]], color='blue')
ax1.plot(batch_size[regular_indices], f1_score[regular_indices], color='blue')
ax1.plot([batch_size[regular_indices[-1]], batch_size[last_index[0]]], [f1_score[regular_indices[-1]], f1_score[last_index[0]]], color='green')
ax1.plot(batch_size[last_index], f1_score[last_index], color='green')

ax2.plot(batch_size[first_two_indices], time_hours[first_two_indices], color='red')
ax2.plot([batch_size[first_two_indices[-1]], batch_size[regular_indices[0]]], [time_hours[first_two_indices[-1]], time_hours[regular_indices[0]]], color='blue')
ax2.plot(batch_size[regular_indices], time_hours[regular_indices], color='blue')
ax2.plot([batch_size[regular_indices[-1]], batch_size[last_index[0]]], [time_hours[regular_indices[-1]], time_hours[last_index[0]]], color='green')
ax2.plot(batch_size[last_index], time_hours[last_index], color='green')

# Add labels next to the first two points
ax1.text(batch_size[first_two_indices[0]]*2.5, f1_score[first_two_indices[0]]+0.08, 'Baseline', fontsize=12, verticalalignment='bottom', horizontalalignment='right', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
ax1.text(batch_size[first_two_indices[1]], f1_score[first_two_indices[1]]+0.07, 'Lamb', fontsize=12, verticalalignment='bottom', horizontalalignment='left', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

ax2.text(batch_size[first_two_indices[0]]*77, time_hours[first_two_indices[0]]-50, 'Baseline', fontsize=12, verticalalignment='bottom', horizontalalignment='right', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
ax2.text(batch_size[first_two_indices[1]]*75, time_hours[first_two_indices[1]]-34, 'Lamb', fontsize=12, verticalalignment='bottom', horizontalalignment='left', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

ax1.set_xscale('log')
ax1.set_xlabel('Batch Size')
ax1.set_ylabel('F1 Score on Dev Set')
ax1.set_title('F1 Score vs Batch Size')
ax1.grid(True)
ax1.xaxis.set_major_formatter(ticker.FuncFormatter(format_k))
ax1.set_xticks(batch_size)
ax1.legend()

ax2.set_xscale('log')
ax2.set_xlabel('Batch Size')
ax2.set_ylabel('Time (hours)')
ax2.set_title('Time vs Batch Size')
ax2.grid(True)
ax2.xaxis.set_major_formatter(ticker.FuncFormatter(format_k))
ax2.set_xticks(batch_size)
ax2.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [129], line 34
#      31 ax2.plot([batch_size[i] for i in regular_indices], [time_hours[i] for i in regular_indices], color='blue', marker='o', label='Mixed-Batch Training')
#      33 # Connect the dots with different colors
# ---> 34 ax1.plot(batch_size[first_two_indices], f1_score[first_two_indices], color='red')
#      35 ax1.plot([batch_size[first_two_indices[-1]], batch_size[regular_indices[0]]], [f1_score[first_two_indices[-1]], f1_score[regular_indices[0]]], color='blue')
#      36 ax1.plot(batch_size[regular_indices], f1_score[regular_indices], color='blue')
#
# TypeError: list indices must be integers or slices, not list

# %%
# Indices for different experiments
first_two_indices = [0, 1]
last_index = [8]
regular_indices = [2, 3, 4, 5, 6, 7]

# Function to format the x-axis labels
def format_k(x, pos):
    if x >= 1000:
        return f'{int(x/1000)}k'
    else:
        return f'{int(x)}'

# Create the first graph (F1 score)
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
# Plot first two points
plt.scatter([batch_size[i] for i in first_two_indices], [f1_score[i] for i in first_two_indices], color='red', marker='s', label='First Two')
# Plot last point
plt.scatter([batch_size[i] for i in last_index], [f1_score[i] for i in last_index], color='green', marker='^', label='Last')
# Plot regular points
plt.scatter([batch_size[i] for i in regular_indices], [f1_score[i] for i in regular_indices], color='blue', marker='o', label='Regular')

# Add labels next to the first two points
plt.text(batch_size[first_two_indices[0]]*0.95, f1_score[first_two_indices[0]]*1.05, 'Baseline', fontsize=12, verticalalignment='bottom', horizontalalignment='right', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
plt.text(batch_size[first_two_indices[1]]*1.05, f1_score[first_two_indices[1]]*1.05, 'Lamb', fontsize=12, verticalalignment='bottom', horizontalalignment='left', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

plt.xscale('log')
plt.xlabel('Batch Size')
plt.ylabel('F1 Score on Dev Set')
plt.title('F1 Score vs Batch Size')
plt.grid(True)
plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(format_k))
plt.xticks(batch_size)
plt.legend()

# Create the second graph (Time)
plt.subplot(1, 2, 2)
# Plot first two points
plt.scatter([batch_size[i] for i in first_two_indices], [time_hours[i] for i in first_two_indices], color='red', marker='s', label='First Two')
# Plot last point
plt.scatter([batch_size[i] for i in last_index], [time_hours[i] for i in last_index], color='green', marker='^', label='Last')
# Plot regular points
plt.scatter([batch_size[i] for i in regular_indices], [time_hours[i] for i in regular_indices], color='orange', marker='o', label='Regular')

# Add labels next to the first two points
plt.text(batch_size[first_two_indices[0]]*0.95, time_hours[first_two_indices[0]]*1.05, 'Baseline', fontsize=12, verticalalignment='bottom', horizontalalignment='right', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))
plt.text(batch_size[first_two_indices[1]]*1.05, time_hours[first_two_indices[1]]*1.05, 'Lamb', fontsize=12, verticalalignment='bottom', horizontalalignment='left', color='black', bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

plt.xscale('log')
plt.xlabel('Batch Size')
plt.ylabel('Time (hours)')
plt.title('Time vs Batch Size')
plt.grid(True)
plt.gca().xaxis.set_major_formatter(ticker.FuncFormatter(format_k))
plt.xticks(batch_size)
plt.legend()

plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.1, wspace=0.4, hspace=0.4)

plt.show()
